# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Third Edition](https://www.manning.com/books/deep-learning-with-python-third-edition). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# The book's contents are available online at [deeplearningwithpython.io](https://deeplearningwithpython.io).

# %%
# !pip install keras keras-hub --upgrade -q

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ## The mathematical building blocks of neural networks

# %% [markdown]
# ### A first look at a neural network

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
import keras
from keras import layers

model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
# ===== Part 1: change first layer size =====
first_layer_sizes = [16, 32, 64, 128, 256, 512]
test_accuracies = []

# Reshape and normalize the images before training
train_images_reshaped = train_images.reshape((60000, 28 * 28))
train_images_reshaped = train_images_reshaped.astype("float32") / 255
test_images_reshaped = test_images.reshape((10000, 28 * 28))
test_images_reshaped = test_images_reshaped.astype("float32") / 255

for size in first_layer_sizes:
    model = keras.Sequential(
        [
            layers.Dense(size, activation="relu"),
            layers.Dense(10, activation="softmax"),
        ]
    )

    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )

    model.fit(
        train_images_reshaped, # Use reshaped images
        train_labels,
        epochs=5,
        batch_size=128,
        verbose=0
    )

    _, test_acc = model.evaluate(test_images_reshaped, test_labels, verbose=0) # Use reshaped images
    test_accuracies.append(test_acc)

    print(f"First layer size {size}: test accuracy = {test_acc:.4f}")
# Out:
# First layer size 16: test accuracy = 0.9365
# First layer size 32: test accuracy = 0.9541
# First layer size 64: test accuracy = 0.9650
# First layer size 128: test accuracy = 0.9736
# First layer size 256: test accuracy = 0.9765
# First layer size 512: test accuracy = 0.9794

# %%
import matplotlib.pyplot as plt

plt.plot(first_layer_sizes, test_accuracies, marker="o")
plt.xlabel("First layer size")
plt.ylabel("Test accuracy")
plt.title("Effect of first layer size on MNIST accuracy")
plt.show()

# %%
model.fit(train_images_reshaped, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9933 - loss: 0.0266
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9951 - loss: 0.0203
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9966 - loss: 0.0145
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9977 - loss: 0.0105
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9979 - loss: 0.0087

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
predictions[0]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# array([[1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01],
#        [1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01],
#        [1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01],
#        [1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01],
#        [1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01],
#        [1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01],
#        [1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01],
#        [3.04735222e-15, 3.66546151e-22, 5.17667006e-36, 7.02925427e-23,
#         6.07444980e-17, 1.55625944e-27, 6.50840363e-12, 1.00000000e+00,
#         3.33210970e-30, 3.37882925e-15],
#        [5.58419857e-21, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         6.02678851e-40, 0.00000000e+00, 1.00000000e+00, 3.02830641e-19,
#         0.00000000e+00, 1.82161564e-30],
#        [1.60769115e-32, 0.00000000e+00, 0.00000000e+00, 1.24715563e-43,
#         0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.94640357e-42,
#         0.00000000e+00, 4.81774426e-26],
#        [2.37975330e-13, 1.26565897e-15, 8.06629435e-41, 9.99955177e-01,
#         2.98146567e-24, 3.85071126e-34, 9.17109446e-06, 1.27052301e-11,
#         1.53568979e-21, 3.56538840e-05],
#        [6.17405703e-06, 4.90673855e-02, 4.07409385e-29, 1.82118058e-01,
#         3.28475198e-11, 1.10151481e-17, 6.78761482e-01, 9.00459364e-02,
#         3.76752232e-12, 9.94882271e-07],
#        [1.87748211e-12, 1.73230469e-03, 9.09308660e-28, 2.08764277e-08,
#         6.22295997e-13, 3.00256261e-07, 9.98267293e-01, 6.22581639e-11,
#         1.28831876e-10, 3.71175096e-12],
#        [1.11547126e-11, 1.03264546e-03, 1.43499251e-22, 5.36849861e-12,
#         1.44358050e-13, 3.17111164e-02, 9.67256248e-01, 2.70040847e-12,
#         4.54430625e-11, 6.06909134e-10],
#        [2.92369989e-10, 1.04673822e-12, 5.49041629e-24, 9.20131097e-17,
#         4.68132187e-16, 9.99998093e-01, 1.89329705e-06, 1.02926199e-13,
#         3.10572995e-16, 6.29319663e-09],
#        [7.24585061e-06, 2.44312921e-11, 9.37052957e-22, 5.57217770e-12,
#         6.99272268e-18, 9.99978542e-01, 1.26280966e-05, 1.33330109e-12,
#         2.13976384e-12, 1.58696400e-06],
#        [9.27887917e-01, 1.27775507e-04, 2.59510526e-18, 3.25807150e-07,
#         2.77929041e-19, 6.20914716e-03, 5.79469139e-03, 3.25840999e-09,
#         1.61921095e-12, 5.99801466e-02],
#        [7.11872766e-04, 1.70313132e-13, 9.05187074e-33, 2.67503832e-11,
#         1.45581292e-24, 7.60867443e-13, 2.34451691e-05, 1.30997609e-11,
#         3.54868755e-18, 9.99264657e-01],
#        [8.29367599e-16, 5.06763614e-24, 0.00000000e+00, 2.67787216e-17,
#         3.40966514e-26, 7.08181142e-25, 3.52152474e-11, 4.53578113e-11,
#         9.73495857e-21, 1.00000000e+00],
#        [1.37500160e-22, 1.04095575e-28, 0.00000000e+00, 7.52671438e-24,
#         3.19938712e-24, 7.38091116e-31, 2.25496222e-15, 9.86289992e-15,
#         6.64924139e-26, 1.00000000e+00],
#        [5.64496637e-16, 4.21662183e-18, 1.05910138e-41, 2.58405456e-20,
#         8.91286600e-09, 5.24397674e-15, 6.60376489e-01, 1.64973679e-09,
#         9.02732823e-27, 3.39623541e-01],
#        [2.43878726e-14, 3.39906461e-13, 8.61961998e-34, 7.04305778e-17,
#         2.05738979e-06, 1.19496927e-17, 9.99997973e-01, 3.94608679e-15,
#         8.59865669e-29, 1.39928042e-08],
#        [2.48939842e-01, 2.04401127e-17, 5.85972355e-32, 5.48066779e-17,
#         3.07246059e-01, 8.17809884e-20, 4.43800986e-01, 2.03736398e-16,
#         3.29071390e-21, 1.31611869e-05],
#        [9.91198467e-04, 4.75416685e-21, 2.53866068e-37, 2.24388534e-21,
#         4.21781745e-03, 2.96035585e-19, 9.94790971e-01, 4.05960971e-18,
#         8.90442721e-25, 6.29823793e-09],
#        [3.68273754e-06, 2.20446036e-24, 5.46506401e-44, 1.64901166e-25,
#         6.75017992e-03, 2.33268407e-18, 9.93246078e-01, 2.94010363e-20,
#         4.03712156e-31, 2.36453715e-15],
#        [2.07261741e-03, 7.72763508e-25, 5.79016525e-42, 2.33510440e-24,
#         1.95105970e-02, 8.22467801e-17, 9.78416800e-01, 1.45973224e-18,
#         1.17244694e-29, 2.08017790e-14],
#        [7.08417118e-01, 3.39011533e-15, 1.81023194e-26, 1.63357834e-11,
#         2.55980082e-02, 5.41020883e-03, 2.60573328e-01, 4.59979242e-11,
#         9.40334040e-18, 1.31546642e-06],
#        [1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01, 1.00000001e-01, 1.00000001e-01,
#         1.00000001e-01, 1.00000001e-01]], dtype=float32)

# %%
predictions[0].argmax()
# Out:
# np.int64(5)

# %%
predictions[0][7]
# Out:
# np.float32(0.10298507)

# %%
test_labels[0]
# Out:
# np.uint8(7)

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"test_acc: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9789 - loss: 0.0718
# test_acc: 0.9819999933242798

# %% [markdown]
# ### Data representations for neural networks

# %% [markdown]
# #### Scalars (rank-0 tensors)

# %%
import numpy as np
x = np.array(12)
x
# Out:
# array(12)

# %%
x.ndim
# Out:
# 0

# %% [markdown]
# #### Vectors (rank-1 tensors)

# %%
x = np.array([12, 3, 6, 14, 7])
x
# Out:
# array([12,  3,  6, 14,  7])

# %%
x.ndim
# Out:
# 1

# %% [markdown]
# #### Matrices (rank-2 tensors)

# %%
x = np.array([[5, 78, 2, 34, 0],
              [6, 79, 3, 35, 1],
              [7, 80, 4, 36, 2]])
x.ndim
# Out:
# 2

# %% [markdown]
# #### Rank-3 tensors and higher-rank tensors

# %%
x = np.array([[[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]],
              [[5, 78, 2, 34, 0],
               [6, 79, 3, 35, 1],
               [7, 80, 4, 36, 2]]])
x.ndim
# Out:
# 3

# %% [markdown]
# #### Key attributes

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images.ndim
# Out:
# 3

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_images.dtype
# Out:
# dtype('uint8')

# %%
import matplotlib.pyplot as plt

digit = train_images[4]
plt.imshow(digit, cmap=plt.cm.binary)
plt.show()

# %%
train_labels[4]
# Out:
# np.uint8(9)

# %% [markdown]
# #### Manipulating tensors in NumPy

# %%
my_slice = train_images[10:100]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[10:100, :, :]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[10:100, 0:28, 0:28]
my_slice.shape
# Out:
# (90, 28, 28)

# %%
my_slice = train_images[:, 14:, 14:]

# %%
my_slice = train_images[:, 7:-7, 7:-7]

# %% [markdown]
# #### The notion of data batches

# %%
batch = train_images[:128]

# %%
batch = train_images[128:256]

# %%
n = 3
batch = train_images[128 * n : 128 * (n + 1)]

# %% [markdown]
# #### Real-world examples of data tensors

# %% [markdown]
# ##### Vector data

# %% [markdown]
# ##### Timeseries data or sequence data

# %% [markdown]
# ##### Image data

# %% [markdown]
# ##### Video data

# %% [markdown]
# ### The gears of neural networks: Tensor operations

# %% [markdown]
# #### Element-wise operations

# %%
def naive_relu(x):
    assert len(x.shape) == 2
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] = max(x[i, j], 0)
    return x

# %%
def naive_add(x, y):
    assert len(x.shape) == 2
    assert x.shape == y.shape
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[i, j]
    return x

# %%
import time

x = np.random.random((20, 100))
y = np.random.random((20, 100))

t0 = time.time()
for _ in range(1000):
    z = x + y
    z = np.maximum(z, 0.0)
print("Took: {0:.2f} s".format(time.time() - t0))
# Out:
# Took: 0.01 s

# %%
t0 = time.time()
for _ in range(1000):
    z = naive_add(x, y)
    z = naive_relu(z)
print("Took: {0:.2f} s".format(time.time() - t0))
# Out:
# Took: 1.68 s

# %% [markdown]
# #### Broadcasting

# %%
import numpy as np

X = np.random.random((32, 10))
y = np.random.random((10,))

# %%
y = np.expand_dims(y, axis=0)

# %%
Y = np.tile(y, (32, 1))

# %%
def naive_add_matrix_and_vector(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    x = x.copy()
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            x[i, j] += y[j]
    return x

# %%
import numpy as np

x = np.random.random((64, 3, 32, 10))
y = np.random.random((32, 10))
z = np.maximum(x, y)

# %% [markdown]
# #### Tensor product

# %%
x = np.random.random((32,))
y = np.random.random((32,))

z = np.matmul(x, y)
z = x @ y

# %%
def naive_vector_product(x, y):
    assert len(x.shape) == 1
    assert len(y.shape) == 1
    assert x.shape[0] == y.shape[0]
    z = 0.0
    for i in range(x.shape[0]):
        z += x[i] * y[i]
    return z

# %%
def naive_matrix_vector_product(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 1
    assert x.shape[1] == y.shape[0]
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        for j in range(x.shape[1]):
            z[i] += x[i, j] * y[j]
    return z

# %%
def naive_matrix_vector_product(x, y):
    z = np.zeros(x.shape[0])
    for i in range(x.shape[0]):
        z[i] = naive_vector_product(x[i, :], y)
    return z

# %%
def naive_matrix_product(x, y):
    assert len(x.shape) == 2
    assert len(y.shape) == 2
    assert x.shape[1] == y.shape[0]
    z = np.zeros((x.shape[0], y.shape[1]))
    for i in range(x.shape[0]):
        for j in range(y.shape[1]):
            row_x = x[i, :]
            column_y = y[:, j]
            z[i, j] = naive_vector_product(row_x, column_y)
    return z

# %% [markdown]
# #### Tensor reshaping

# %%
train_images = train_images.reshape((60000, 28 * 28))

# %%
x = np.array([[0., 1.],
              [2., 3.],
              [4., 5.]])
x.shape
# Out:
# (3, 2)

# %%
x = x.reshape((6, 1))
x
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [3.],
#        [4.],
#        [5.]])

# %%
x = x.reshape((2, 3))
x
# Out:
# array([[0., 1., 2.],
#        [3., 4., 5.]])

# %%
x = np.zeros((300, 20))
x = np.transpose(x)
x.shape
# Out:
# (20, 300)

# %% [markdown]
# #### Geometric interpretation of tensor operations

# %% [markdown]
# #### A geometric interpretation of deep learning

# %% [markdown]
# ### The engine of neural networks: Gradient-based optimization

# %% [markdown]
# #### What's a derivative?

# %% [markdown]
# #### Derivative of a tensor operation: The gradient

# %% [markdown]
# #### Stochastic gradient descent

# %% [markdown]
# #### Chaining derivatives: The Backpropagation algorithm

# %% [markdown]
# ##### The chain rule

# %% [markdown]
# ##### Automatic differentiation with computation graphs

# %% [markdown]
# ### Looking back at our first example

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype("float32") / 255

# %%
model = keras.Sequential(
    [
        layers.Dense(512, activation="relu"),
        layers.Dense(10, activation="softmax"),
    ]
)

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)

# %%
model.fit(
    train_images,
    train_labels,
    epochs=5,
    batch_size=128,
)
# Out:
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8678 - loss: 0.4571
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9658 - loss: 0.1193
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9793 - loss: 0.0730
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9848 - loss: 0.0517
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9890 - loss: 0.0383

# %% [markdown]
# #### Reimplementing our first example from scratch

# %% [markdown]
# ##### A simple Dense class

# %%
import keras
from keras import ops

class NaiveDense:
    def __init__(self, input_size, output_size, activation=None):
        self.activation = activation
        self.W = keras.Variable(
            shape=(input_size, output_size), initializer="uniform"
        )
        self.b = keras.Variable(shape=(output_size,), initializer="zeros")

    def __call__(self, inputs):
        x = ops.matmul(inputs, self.W)
        x = x + self.b
        if self.activation is not None:
            x = self.activation(x)
        return x

    @property
    def weights(self):
        return [self.W, self.b]

# %% [markdown]
# ##### A simple Sequential class

# %%
class NaiveSequential:
    def __init__(self, layers):
        self.layers = layers

    def __call__(self, inputs):
        x = inputs
        for layer in self.layers:
            x = layer(x)
        return x

    @property
    def weights(self):
        weights = []
        for layer in self.layers:
            weights += layer.weights
        return weights

# %%
model = NaiveSequential(
    [
        NaiveDense(input_size=28 * 28, output_size=512, activation=ops.relu),
        NaiveDense(input_size=512, output_size=10, activation=ops.softmax),
    ]
)
assert len(model.weights) == 4

# %% [markdown]
# ##### A batch generator

# %%
import math

class BatchGenerator:
    def __init__(self, images, labels, batch_size=128):
        assert len(images) == len(labels)
        self.index = 0
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.num_batches = math.ceil(len(images) / batch_size)

    def next(self):
        images = self.images[self.index : self.index + self.batch_size]
        labels = self.labels[self.index : self.index + self.batch_size]
        self.index += self.batch_size
        return images, labels

# %% [markdown]
# #### Running one training step

# %% [markdown]
# ##### The weight update step

# %%
learning_rate = 1e-3

def update_weights(gradients, weights):
    for g, w in zip(gradients, weights):
        w.assign(w - g * learning_rate)

# %%
from keras import optimizers

optimizer = optimizers.SGD(learning_rate=1e-3)

def update_weights(gradients, weights):
    optimizer.apply_gradients(zip(gradients, weights))

# %% [markdown]
# ##### Gradient computation

# %%
# %%backend tensorflow
# import tensorflow as tf
#
# x = tf.zeros(shape=())
# with tf.GradientTape() as tape:
#     y = 2 * x + 3
# grad_of_y_wrt_x = tape.gradient(y, x)

# %%
# %%backend tensorflow
# def one_training_step(model, images_batch, labels_batch):
#     with tf.GradientTape() as tape:
#         predictions = model(images_batch)
#         loss = ops.sparse_categorical_crossentropy(labels_batch, predictions)
#         average_loss = ops.mean(loss)
#     gradients = tape.gradient(average_loss, model.weights)
#     update_weights(gradients, model.weights)
#     return average_loss

# %% [markdown]
# #### The full training loop

# %%
# %%backend tensorflow
# def fit(model, images, labels, epochs, batch_size=128):
#     for epoch_counter in range(epochs):
#         print(f"Epoch {epoch_counter}")
#         batch_generator = BatchGenerator(images, labels)
#         for batch_counter in range(batch_generator.num_batches):
#             images_batch, labels_batch = batch_generator.next()
#             loss = one_training_step(model, images_batch, labels_batch)
#             if batch_counter % 100 == 0:
#                 print(f"loss at batch {batch_counter}: {loss:.2f}")

# %%
# %%backend tensorflow
# from keras.datasets import mnist
#
# (train_images, train_labels), (test_images, test_labels) = mnist.load_data()
#
# train_images = train_images.reshape((60000, 28 * 28))
# train_images = train_images.astype("float32") / 255
# test_images = test_images.reshape((10000, 28 * 28))
# test_images = test_images.astype("float32") / 255
#
# fit(model, train_images, train_labels, epochs=10, batch_size=128)
# Out:
# Epoch 0
# loss at batch 0: 2.34
# loss at batch 100: 2.27
# loss at batch 200: 2.23
# loss at batch 300: 2.21
# loss at batch 400: 2.17
# Epoch 1
# loss at batch 0: 2.14
# loss at batch 100: 2.12
# loss at batch 200: 2.06
# loss at batch 300: 2.04
# loss at batch 400: 2.00
# Epoch 2
# loss at batch 0: 1.96
# loss at batch 100: 1.96
# loss at batch 200: 1.87
# loss at batch 300: 1.85
# loss at batch 400: 1.82
# Epoch 3
# loss at batch 0: 1.77
# loss at batch 100: 1.78
# loss at batch 200: 1.67
# loss at batch 300: 1.66
# loss at batch 400: 1.64
# Epoch 4
# loss at batch 0: 1.57
# loss at batch 100: 1.60
# loss at batch 200: 1.47
# loss at batch 300: 1.47
# loss at batch 400: 1.47
# Epoch 5
# loss at batch 0: 1.38
# loss at batch 100: 1.42
# loss at batch 200: 1.28
# loss at batch 300: 1.30
# loss at batch 400: 1.31
# Epoch 6
# loss at batch 0: 1.21
# loss at batch 100: 1.27
# loss at batch 200: 1.12
# loss at batch 300: 1.15
# loss at batch 400: 1.18
# Epoch 7
# loss at batch 0: 1.07
# loss at batch 100: 1.13
# loss at batch 200: 0.98
# loss at batch 300: 1.03
# loss at batch 400: 1.07
# Epoch 8
# loss at batch 0: 0.96
# loss at batch 100: 1.02
# loss at batch 200: 0.88
# loss at batch 300: 0.93
# loss at batch 400: 0.99
# Epoch 9
# loss at batch 0: 0.87
# loss at batch 100: 0.93
# loss at batch 200: 0.79
# loss at batch 300: 0.85
# loss at batch 400: 0.92

# %% [markdown]
# #### Evaluating the model

# %%
# %%backend tensorflow
# predictions = model(test_images)
# predicted_labels = ops.argmax(predictions, axis=1)
# matches = predicted_labels == test_labels
# f"accuracy: {ops.mean(matches):.2f}"
# Out:
# 'accuracy: 0.84'
